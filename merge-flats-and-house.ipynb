# %%
import numpy as np
import pandas as pd

# %%
flats = pd.read_csv('flats_cleaned.csv')
houses = pd.read_csv('house_cleaned.csv')

# %%
df = pd.concat([flats,houses],ignore_index=True)

# %%
# done to shuffle the data randomly
df = df.sample(df.shape[0],ignore_index=True)

# %%
df.head()
# Out:
#                                        property_name property_type  \
# 0                    3 BHK Flat in Sector 92 Gurgaon          flat
# 1  6 Bedroom House for sale in Palam Vihar Extension         house
# 2                    3 BHK Flat in Sector 61 Gurgaon          flat
# 3                    3 BHK Flat in Sector 79 Gurgaon          flat
# 4      4 Bedroom House for sale in Sector 82 Gurgaon         house
#
#                                society  price  price_per_sqft    area  \
# 0                           sare homes   0.65          4587.0  1417.0
# 1  palam vihar extension west zone rwa   0.40          4444.0   900.0
# 2                  smart world orchard   2.41         14785.0  1630.0
# 3                       bestech altura   2.69         12500.0  2152.0
# 4                    vatika india next   6.50         20062.0  3240.0
#
#                                         areaWithType  bedRoom  bathroom  \
# 0                   Carpet area: 1417 (131.64 sq.m.)        3         3
# 1                         Plot area 900(83.61 sq.m.)        6         4
# 2  Built Up area: 1630 (151.43 sq.m.)Carpet area:...        3         3
# 3             Super Built up area 2150(199.74 sq.m.)        3         4
# 4  Built Up area: 360 (301.01 sq.m.)Carpet area: ...        4         3
#
#   balcony additionalRoom                                            address  \
# 0       2  not available          Sare, Sector 92 Gurgaon, Gurgaon, Haryana
# 1       2  not available            Palam Vihar Extension, Gurgaon, Haryana
# 2       3  not available     Sector 61, Sector 61 Gurgaon, Gurgaon, Haryana
# 3      3+   servant room  Tower F, 3rd Floor, Sector 79 Gurgaon, Gurgaon...
# 4       0  not available     Sector 82, Sector 82 Gurgaon, Gurgaon, Haryana
#
#    floorNum facing     agePossession  \
# 0       3.0    NaN   1 to 5 Year Old
# 1       2.0   West  5 to 10 Year Old
# 2       2.0   East   Within 3 months
# 3       3.0    NaN   0 to 1 Year Old
# 4       2.0    NaN         undefined
#
#                                      nearbyLocations  \
# 0  ['Yadav Clinic', 'Bangali Clinic', 'Dr. J. S. ...
# 1  ['Palam triangle', 'Palam Vihar Vyapar kendra'...
# 2  ['Sector 55-56 Metro station', 'Bestech Centra...
# 3  ['Sapphire 83 Mall', 'NH -8', 'Golf Course Ext...
# 4  ['Sapphire 83 Mall', 'Dwarka expressway', 'Del...
#
#                                          description  \
# 0  Sun facing unit for sale for visit feel free t...
# 1  It has the rental income upto 20k, double stor...
# 2  Best in class property available at sector 61 ...
# 3  Tower f \n3rd floor\nCorner property \nSwimmin...
# 4  4bhk villa for resale in vatika india next at ...
#
#                                       furnishDetails  \
# 0                                                NaN
# 1                                                NaN
# 2  ['1 Exhaust Fan', '1 Light', '1 Modular Kitche...
# 3  ['4 AC', 'No Bed', 'No Chimney', 'No Curtains'...
# 4                                                NaN
#
#                                             features  \
# 0                              ['Maintenance Staff']
# 1  ['Water purifier', 'Water Storage', 'Park', 'V...
# 2                                                NaN
# 3  ['Feng Shui / Vaastu Compliant', 'Security / F...
# 4                                                NaN
#
#                                               rating
# 0  ['Environment5 out of 5', 'Lifestyle4 out of 5...
# 1  ['Environment4 out of 5', 'Lifestyle4 out of 5...
# 2                                                NaN
# 3  ['Environment4 out of 5', 'Lifestyle3 out of 5...
# 4  ['Environment4 out of 5', 'Lifestyle4 out of 5...

# %%
df.shape
# Out:
# (3961, 20)

# %%
df.to_csv('gurgaon_properties.csv',index=False)
